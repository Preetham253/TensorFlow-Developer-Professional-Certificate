# %% [markdown]
# # Ungraded Lab: Improving Computer Vision Accuracy using Convolutions

# %% [markdown]
# # Shallow Neural Network

# %%
import tensorflow as tf
# Load the Fashion MNIST dataset
fmnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fmnist.load_data()
#Normalize the pixel values
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Model without Convolutional layers

# %%
#Define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation=tf.nn.relu),
    tf.keras.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
from tensorflow.keras.losses import sparse_categorical_crossentropy
#Training parameters
model.compile(optimizer='adam',loss=sparse_categorical_crossentropy,metrics=['accuracy'])
#Train the model
model.fit(train_images,train_labels,epochs=5)
#Evaluate on test set
print('\n Evaluation of model on test set')
test_loss = model.evaluate(test_images,test_labels)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4973 - accuracy: 0.8246
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3753 - accuracy: 0.8641
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3378 - accuracy: 0.8780
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3114 - accuracy: 0.8856
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2957 - accuracy: 0.8905
#
#  Evaluation of model on test set
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3602 - accuracy: 0.8694

# %% [markdown]
# Model with convolutional layers

# %%
model = tf.keras.models.Sequential([
    #adding convolutional and max pooling layers
    tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    #addiing the remaining layers
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_2 (Dense)             (None, 256)               409856
#
#  dense_3 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 449994 (1.72 MB)
# Trainable params: 449994 (1.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam',loss=sparse_categorical_crossentropy,metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=5)
print('\n Evaluation of model on test set')
test_loss = model.evaluate(test_images,test_labels)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 86s 45ms/step - loss: 0.4253 - accuracy: 0.8461
# Epoch 2/5
# 1875/1875 [==============================] - 83s 44ms/step - loss: 0.2846 - accuracy: 0.8952
# Epoch 3/5
# 1875/1875 [==============================] - 87s 46ms/step - loss: 0.2386 - accuracy: 0.9117
# Epoch 4/5
# 1875/1875 [==============================] - 82s 44ms/step - loss: 0.2036 - accuracy: 0.9238
# Epoch 5/5
# 1875/1875 [==============================] - 82s 44ms/step - loss: 0.1740 - accuracy: 0.9336
#
#  Evaluation of model on test set
# 313/313 [==============================] - 4s 11ms/step - loss: 0.2549 - accuracy: 0.9121
